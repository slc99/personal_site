# %% [raw]
# ---
# title: "This is a test"
# date: "2025-01-16"
# categories: [ayo, lamao]
# description: "Does this work?"
# ---

# %% [markdown]
# # Big Leagues

# %% [markdown]
# Everyone know my favorite number is

# %%
Test $\delta \leq \phi$ so there
# Out:
#   Cell In[2], line 1
#     Test $\delta \leq \phi$ so there
#          ^
# SyntaxError: invalid syntax
